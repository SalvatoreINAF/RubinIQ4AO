# %%
import numpy as np
import pandas as pd

import lsst.geom as geom
from lsst.geom import PointD
from lsst.geom import Point2D
import lsst.afw.display as afwDisplay
import lsst.daf.base as dafBase
from lsst.daf.butler import Butler
import lsst.afw.image as afwImage
import lsst.afw.table as afwTable
from lsst.afw.geom.ellipses import Quadrupole, SeparableDistortionTraceRadius
from lsst.afw import cameraGeom
from lsst.daf.butler import Butler

from ellipticity_mapping import calculate_ellipticity_on_xy
from ellipticity_mapping import remove_figure
from ellipticity_mapping import plot_ellipticitymap
import matplotlib.pyplot as plt
from rotation_conversion import rsp_to_rtp
# %matplotlib widget

import datetime
import time

# %%
timestamp = time.time()  # Example timestamp
datetime_object = datetime.datetime.fromtimestamp(timestamp)
formatted_datetime = datetime_object.strftime("%Y%m%dT%H%M%S")

# %%
def pixel_to_camera(x, y, det):
    """
    Parameters
    ----------
    x, y : array
        Pixel coordinates.
    det : lsst.afw.cameraGeom.Detector
        Detector of interest.
    Returns
    -------
    cam_x, cam_y : array
        Focal plane position in millimeters in DVCS
        See https://lse-349.lsst.io/
    """
    tx = det.getTransform(cameraGeom.PIXELS, cameraGeom.FOCAL_PLANE)
    cam_x, cam_y = tx.getMapping().applyForward(np.vstack((x, y)))
    return cam_x.ravel(), cam_y.ravel()

def pixel_to_camera_angle(x, y, det):
    """
    Parameters
    ----------
    x, y : array
        Pixel coordinates.lsst afw.detectordetectordetectordetector
    det : lsst.afw.cameraGeom.Detector
        Detector of interest.
    Returns
    -------
    cam_x, cam_y : array
        Focal plane position in degrees in DVCS
        See https://lse-349.lsst.io/
    """
    tx = det.getTransform(cameraGeom.PIXELS, cameraGeom.FIELD_ANGLE)
    cam_x, cam_y = tx.getMapping().applyForward(np.vstack((x, y)))
    return np.degrees(cam_x.ravel()), np.degrees(cam_y.ravel())

# %%
folder = '/sdf/data/rubin/shared/image_quality/imsim/'
#Define the butler data configuration and collection (una tantum )
config = folder+'repo'
folderout = folder+'ellipticitymap/'
subfolderout_fig = 'figures/'
subfolderout_tab = 'tables/'
string_grid_or_star = ['grid', 'stars', 'detcenter']

# %%
visit_ids = [7024062500039, 7024062500078, 7024062500105, 7024062500126]
visit_ids = [7024062600099]
detectors = list(np.arange(9))
figure_size_degrees = .5

# %%
repo = 'embargo_or4'
butler = Butler(repo, collections='LSSTComCamSim/nightlyValidation')

# %%
string_dataset = 'OR4'
format_figures = 'png'

# %%
do_make_figures_calexp = False
do_make_ellipticity_in_the_center = True
do_make_mean_ellipticity = True
do_ellipticity_detector_center = True
do_ellipticity_grid = True
regular_grid_or_star_positions = 1 # parametro per l'ellitticità su singolo detector 
# 0: calcolo ellitticità su griglia; 1: calcolo ellitticità su posizioni stelle
n_grid = 5

do_figure_wcs = False
do_figure_bkg = False
do_figure_psf = False
do_fits_preview = False

# OUTPUT ELLITTICITÀ MEDIE SUI DETECTOR
detector_detcentermean = []
visitid_detcentermean = []
mean_e_detcentermean = []
median_e_detcentermean = []
std_e_detcentermean = []
min_e_detcentermean = []
max_e_detcentermean = []
xx_rot_detcentermean_dvcs = []
yy_rot_detcentermean_dvcs = []

xx_detcenter_output = []
yy_detcenter_output = []

# OUTPUT ELLITTICITÀ MEDIE SULLE SINGOLE STELLE O GRIGLIA
visitid_star_output = []
detector_star_output = []

x_centro_detector = 2000.
y_centro_detector = 2000.

for visitid in visit_ids:

    # output di tabella di ellitticità per il centro di ogni detector [DVCS]
    visitid_detcenter_output = []
    detector_detcenter_output = []

    xx_rot_detcenter_dvcs_forfigure = []
    yy_rot_detcenter_dvcs_forfigure = []
    ex_detcenter_dvcs_forfigure = []
    ey_detcenter_dvcs_forfigure = []
    e_detcenter_forfigure = []

    xx_rot_grid_dvcs_forfigure = []
    yy_rot_grid_dvcs_forfigure = []
    ex_grid_dvcs_forfigure = []
    ey_grid_dvcs_forfigure = []
    e_grid_forfigure = []
    
    xx_rot_star_dvcs_forfigure = []
    yy_rot_star_dvcs_forfigure = []
    ex_star_dvcs_forfigure = []
    ey_star_dvcs_forfigure = []
    e_star_forfigure = []
    
    for detector in detectors:
                
        print(visitid, detector)

        dataId = {'visit': visitid, 'detector': detector, 'physical_filter': 'i_06'}
        datasetType='calexp'
        calexp = butler.get(datasetType, **dataId)
        sources = butler.get('src', dataId)
        psf = calexp.getPsf()
        bkgd = butler.get('calexpBackground', **dataId)
        ccd = calexp.detector.getId()
        det = calexp.getDetector()
        wcs = calexp.getWcs()
        calexp_info = calexp.getInfo()

        print(calexp.info.getMetadata())
        assert False
        
        rotskypos = (calexp.info.getVisitInfo().getBoresightRotAngle()).asDegrees()
        rottelpos = rsp_to_rtp(rotskypos, \
            (calexp.info.getVisitInfo().getBoresightRaDec())[0].asDegrees(), \
            (calexp.info.getVisitInfo().getBoresightRaDec())[1].asDegrees(), \
            calexp.info.getVisitInfo().getDate().toAstropy()).deg
        rottelpos_radians = np.radians(rottelpos)

        if do_ellipticity_detector_center:

            e_detcenter, ex_detcenter_dvcs, ey_detcenter_dvcs, ex_rot_detcenter_dvcs, ey_rot_detcenter_dvcs, \
                e1, e2, xx_detcenter_dvcs, yy_detcenter_dvcs, theta_detcenter_dvcs, \
                xx_rot_detcenter_dvcs, yy_rot_detcenter_dvcs, ra_detcenter_dvcs, dec_detcenter_dvcs, fwhm, size = \
                calculate_ellipticity_on_xy(calexp, sources, psf, 2, n_grid,
                fileout=folderout+subfolderout_tab+
                'ellipticitymap_'+string_grid_or_star[2]+'_visitid{:04d}_det{:03d}_wihderotation.csv'.format(visitid, detector))
            visitid_detcenter_output = [visitid] * len(e_detcenter)
            detector_detcenter_output = [detector] * len(e_detcenter)
            xx_rot_detcenter_dvcs_forfigure.append(xx_rot_detcenter_dvcs)
            yy_rot_detcenter_dvcs_forfigure.append(yy_rot_detcenter_dvcs)
            ex_detcenter_dvcs_forfigure.append(ex_rot_detcenter_dvcs)
            ey_detcenter_dvcs_forfigure.append(ey_rot_detcenter_dvcs)
            e_detcenter_forfigure.append(e_detcenter)
        
    #################################        
    # Display figures (inizio)
    #################################        
        if do_make_figures_calexp:
            if do_fits_preview:
                fig = plt.figure()
                #Display the image with lsst.afw.display
    
                #The next task is to let AFWDisplay know that we want it to use matplotlib as our default display backend.
                #To do this, we use the setDefaultBackend() function. Remember that we made an alias to lsst.afw.display called afwDisplay in the import
                afwDisplay.setDefaultBackend('matplotlib')
                # get an alias to the lsst.afw.display.Display() method
                display = afwDisplay.Display(frame=fig)
                # set the image stretch algorithm and range
                display.scale('asinh', 'zscale')
                # load the image into the display
                display.mtv(calexp.image)
                # show the corresponding pyplot figure
                plt.title("Image VisitID {:13d} Detector {:03d}".format(visitid,detector))
                plt.show()
                # clean up memory
                remove_figure(fig)

            #Esiste un tutorial per l'utilizzo di  afw_display che il numero 3 del tutorial, da studiare perche' questo e' lo standard, 
            #in particolare fornisce funzioi su come fare i cut, le composizioni di immagini  etc...)
            #https://github.com/rubin-dp0/tutorial-notebooks/blob/main/03a_Image_Display_and_Manipulation.ipynb
            #invece il noteook dopo va su strumenti un po' piu' potenti di data display come firefly che ti apre figure iterattive che credo sia il caso di imparare

            if do_figure_wcs:
                #Figura con WCS
                fig = plt.figure()
                plt.subplot(projection=WCS(calexp.getWcs().getFitsMetadata()))
                calexp_extent = (calexp.getBBox().beginX, calexp.getBBox().endX,
                                 calexp.getBBox().beginY, calexp.getBBox().endY)
                im = plt.imshow(calexp.image.array, cmap='gray', vmin=-200.0, vmax=400,
                                extent=calexp_extent, origin='lower')
                plt.grid(color='white', ls='solid')
                plt.xlabel('Right Ascension')
                plt.ylabel('Declination')
                plt.show()
                remove_figure(fig)\

            if do_figure_psf:
                #EXPLORE PSF
                #The PSF object can be used to get a realization of a PSF at a specific point
                fig = plt.figure()
                psfimage = psf.computeImage(PointD(x_centro_detector, y_centro_detector))
                display = afwDisplay.Display()
                display.scale('asinh', min=0.0, max=1.e-3, unit='absolute')
                display.mtv(psfimage)
                plt.title("PSF at 2000 2000 VisitID {:13d} Detector {:03d}".format(visitid,detector))
                plt.show()
                remove_figure(fig)

            #Visualize
            afwDisplay.setDefaultBackend('matplotlib')

            if do_figure_bkg:
                fig = plt.figure()
                afw_display = afwDisplay.Display()
                afw_display.scale('linear', 'zscale')
                afw_display.mtv(bkgd.getImage())
                plt.title("Local Polynomial Background VisitID {:13d} Detector {:03d}".format(visitid,detector))
                plt.show()
                # remove_figure(fig)
    #################################        
    #Display figures (FINE)
    #################################        

#     #################################        
#     # Ellipticity on grid su singolo detector (inizio)
#     #################################        
        if True:

            e_star, ex_star_dvcs, ey_star_dvcs, ex_rot_star_dvcs, ey_rot_star_dvcs, \
                e1, e2, xx_star_dvcs, yy_star_dvcs, theta_star_dvcs, \
                xx_rot_star_dvcs, yy_rot_star_dvcs, ra_star_dvcs, dec_star_dvcs, fwhm, size = \
                calculate_ellipticity_on_xy(calexp, sources, psf, regular_grid_or_star_positions, n_grid,
                fileout=folderout+subfolderout_tab+
                'ellipticitymap_'+string_grid_or_star[regular_grid_or_star_positions]+
                '_visitid{:13d}_det{:03d}_wihderotation.csv'.format(visitid, detector))
            visitid_star_output = [visitid] * len(e_star)
            detector_star_output = [detector] * len(e_star)

        # Statistica sulle ellitticità
            mean_e = np.mean(e_star)
            median_e = np.median(e_star)
            std_e = np.std(e_star)
            min_e = min(e_star)
            max_e = max(e_star)

        ### plotto la figura con gli ellipticity sticks sulla griglia nel detector            
            fig = plt.figure(figsize=(8, 6))
            plt.quiver(xx_rot_star_dvcs, yy_rot_star_dvcs, 
                       ex_rot_star_dvcs, ey_rot_star_dvcs, e_star, 
                       headlength=0., headwidth=1., pivot='mid', width=0.005)
            colorbar = plt.colorbar(label='e')
            plt.clim(0., max(e_star))
            plt.xlabel('x (DVCS)')
            plt.ylabel('y (DVCS)')
            plt.title('Ellipticity Sticks')
            fig.savefig(folderout+subfolderout_fig+
                        'Ellipticity_Sticks_'+string_grid_or_star[regular_grid_or_star_positions]+
                        '_'+string_dataset+'_DVCS_visitid{:13d}_det{:03d}_wihderotation.{:s}'.format(visitid,detector,format_figures))
            remove_figure(fig)
            
            e_grid, ex_grid_dvcs, ey_grid_dvcs, ex_rot_grid_dvcs, ey_rot_grid_dvcs, \
                e1, e2, xx_grid_dvcs, yy_grid_dvcs, theta_grid_dvcs, \
                xx_rot_grid_dvcs, yy_rot_grid_dvcs, ra_grid_dvcs, dec_grid_dvcs, fwhm, size = \
                calculate_ellipticity_on_xy(calexp, sources, psf, 0, n_grid,
                fileout=folderout+subfolderout_tab+
                'ellipticitymap_'+string_grid_or_star[0]+
                '_visitid{:13d}_det{:03d}.csv'.format(visitid, detector))
            
            visitid_grid_output = [visitid] * len(e_grid)
            detector_grid_output = [detector] * len(e_grid)
            xx_rot_grid_dvcs_forfigure.append(xx_rot_grid_dvcs)
            yy_rot_grid_dvcs_forfigure.append(yy_rot_grid_dvcs)
            ex_grid_dvcs_forfigure.append(ex_rot_grid_dvcs)
            ey_grid_dvcs_forfigure.append(ey_rot_grid_dvcs)
            e_grid_forfigure.append(e_grid)

            e_star, ex_star_dvcs, ey_star_dvcs, ex_rot_star_dvcs, ey_rot_star_dvcs, \
                e1, e2, xx_star_dvcs, yy_star_dvcs, theta_star_dvcs, \
                xx_rot_star_dvcs, yy_rot_star_dvcs, ra_star_dvcs, dec_star_dvcs, fwhm, size = \
                calculate_ellipticity_on_xy(calexp, sources, psf, 1, n_grid,
                fileout=folderout+subfolderout_tab+
                'ellipticitymap_'+string_grid_or_star[1]+
                '_visitid{:13d}_det{:03d}.csv'.format(visitid, detector))
            
            visitid_star_output = [visitid] * len(e_star)
            detector_star_output = [detector] * len(e_star)
            xx_rot_star_dvcs_forfigure.append(list(xx_rot_star_dvcs))
            yy_rot_star_dvcs_forfigure.append(list(yy_rot_star_dvcs))
            ex_star_dvcs_forfigure.append(list(ex_rot_star_dvcs))
            ey_star_dvcs_forfigure.append(list(ey_rot_star_dvcs))
            e_star_forfigure.append(list(e_star))

    #################################        
    # Ellipticity on grid su singolo detector (fine)
    #################################

#     #################################
#     #    OUTPUT TABLE MEAN ELLIPTICITIES
#     #################################

        point = Point2D(x_centro_detector, y_centro_detector)
        cam_x, cam_y = pixel_to_camera_angle(point[0], point[1], det)
        xx_rot = np.asarray(cam_x[0])*np.cos(rottelpos_radians) - \
                                np.asarray(cam_y[0])*np.sin(rottelpos_radians)
        yy_rot = np.asarray(cam_x[0])*np.sin(rottelpos_radians) + \
                                np.asarray(cam_y[0])*np.cos(rottelpos_radians)
        
        xx_rot_detcentermean_dvcs.append(yy_rot) #IMPORTANTE INVERTIRE XY TRA CCS E DVCS
        yy_rot_detcentermean_dvcs.append(xx_rot) #IMPORTANTE INVERTIRE XY TRA CCS E DVCS
        detector_detcentermean.append(detector)
        visitid_detcentermean.append(visitid)
        mean_e_detcentermean.append(mean_e)
        median_e_detcentermean.append(median_e)
        std_e_detcentermean.append(std_e)
        min_e_detcentermean.append(min_e)
        max_e_detcentermean.append(max_e)
    
    # Figura ellitticità al centro su tutti i detector (una per ogni visitid)
    if do_ellipticity_detector_center:
        fig = plt.figure(figsize=(10,8))
        plt.quiver(xx_rot_detcenter_dvcs_forfigure, yy_rot_detcenter_dvcs_forfigure, 
                   ex_detcenter_dvcs_forfigure, ey_detcenter_dvcs_forfigure, e_detcenter_forfigure,  
                   scale=.5, headlength=0., headwidth=1., pivot='mid', linewidths=.01)

        colorbar = plt.colorbar(label='ellipticity')
        plt.clim(min(e_detcenter_forfigure), max(e_detcenter_forfigure))
        plt.xlim([-figure_size_degrees,figure_size_degrees])
        plt.ylim([-figure_size_degrees,figure_size_degrees])
        plt.xlabel('x [deg]')
        plt.ylabel('y [deg]')
        plt.title('Ellipticity Sticks')
        fig.savefig(folderout+"figures/Ellipticity_Sticks_detcenter_DVCS_"+string_dataset+
                    "_visitid{:13d}_wihderotation.{:s}".format(visitid,format_figures))
        remove_figure(fig)

    e_grid_forfigure = np.asarray(e_grid_forfigure).flatten()
    xx_rot_grid_dvcs_forfigure = np.asarray(xx_rot_grid_dvcs_forfigure).flatten()
    yy_rot_grid_dvcs_forfigure = np.asarray(yy_rot_grid_dvcs_forfigure).flatten()
    ex_grid_dvcs_forfigure = np.asarray(ex_grid_dvcs_forfigure).flatten()
    ey_grid_dvcs_forfigure = np.asarray(ey_grid_dvcs_forfigure).flatten()

    e_star_forfigure = sum([sublist for sublist in e_star_forfigure], [])
    xx_rot_star_dvcs_forfigure = sum([sublist for sublist in xx_rot_star_dvcs_forfigure], [])
    yy_rot_star_dvcs_forfigure = sum([sublist for sublist in yy_rot_star_dvcs_forfigure], [])
    ex_star_dvcs_forfigure = sum([sublist for sublist in ex_star_dvcs_forfigure], [])
    ey_star_dvcs_forfigure = sum([sublist for sublist in ey_star_dvcs_forfigure], [])
    
    e_star_forfigure = np.asarray(e_star_forfigure).flatten()
    xx_rot_star_dvcs_forfigure = np.asarray(xx_rot_star_dvcs_forfigure).flatten()
    yy_rot_star_dvcs_forfigure = np.asarray(yy_rot_star_dvcs_forfigure).flatten()
    ex_star_dvcs_forfigure = np.asarray(ex_star_dvcs_forfigure).flatten()
    ey_star_dvcs_forfigure = np.asarray(ey_star_dvcs_forfigure).flatten()
    
    # Figura ellitticità su griglia tutti i detector (una per ogni visitid)
    if do_ellipticity_grid:
        fig = plt.figure(figsize=(10,8))
        plt.quiver(xx_rot_grid_dvcs_forfigure, yy_rot_grid_dvcs_forfigure, 
                   ex_grid_dvcs_forfigure, ey_grid_dvcs_forfigure, e_grid_forfigure,  
                   scale=.5, headlength=0., headwidth=1., pivot='mid', linewidths=.01)

        colorbar = plt.colorbar(label='ellipticity')
        plt.clim(min(e_grid_forfigure), max(e_grid_forfigure))
        plt.xlim([-figure_size_degrees,figure_size_degrees])
        plt.ylim([-figure_size_degrees,figure_size_degrees])
        plt.xlabel('x [deg]')
        plt.ylabel('y [deg]')
        plt.title('Ellipticity Sticks')
        fig.savefig(folderout+"figures/Ellipticity_Sticks_DVCS_"+string_grid_or_star[0]+"_"+string_dataset+
                    "_visitid{:13d}_wihderotation.{:s}".format(visitid,format_figures))
        remove_figure(fig)

        fig = plt.figure(figsize=(10,8))
        plt.quiver(xx_rot_star_dvcs_forfigure, yy_rot_star_dvcs_forfigure, 
                   ex_star_dvcs_forfigure, ey_star_dvcs_forfigure, e_star_forfigure,  
                   scale=.5, headlength=0., headwidth=1., pivot='mid', linewidths=.0001)

        colorbar = plt.colorbar(label='ellipticity')
        plt.clim(min(e_grid_forfigure), max(e_grid_forfigure))
        plt.xlim([-figure_size_degrees,figure_size_degrees])
        plt.ylim([-figure_size_degrees,figure_size_degrees])
        plt.xlabel('x [deg]')
        plt.ylabel('y [deg]')
        plt.title('Ellipticity Sticks')
        fig.savefig(folderout+"figures/Ellipticity_Sticks_DVCS_"+string_grid_or_star[1]+"_"+string_dataset+
                    "_visitid{:13d}_wihderotation.{:s}".format(visitid,format_figures))
        remove_figure(fig)

# TABELLA ELLITTICITÀ MEDIE SU FOCALPLANE
df = pd.DataFrame(data={'detector': detector_detcentermean, 'visitid': visitid_detcentermean, 
                        'xx_rot_detcentermean_dvcs': xx_rot_detcentermean_dvcs, 
                        'yy_rot_detcentermean_dvcs': yy_rot_detcentermean_dvcs, 
                        'mean_e': mean_e_detcentermean, 'median_e': median_e_detcentermean, 
                        'std_e': std_e_detcentermean, 'min_e': min_e_detcentermean, 
                        'max_e': max_e_detcentermean})
df.to_csv(folderout+subfolderout_tab+'mean_ellipticities_DVCS_'+string_dataset+
          '_'+formatted_datetime+'_wihderotation.csv', index=False)
# Out:
# 7024062500024 0
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[9], line 66
#      64 dataId = {'visit': visitid, 'detector': detector, 'physical_filter': 'i_06'}
#      65 datasetType='calexp'
# ---> 66 calexp = butler.get(datasetType, **dataId)
#      67 sources = butler.get('src', dataId)
#      68 psf = calexp.getPsf()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-9.0.0/share/eups/Linux64/daf_butler/g427f673a11+89552d51e6/python/lsst/daf/butler/direct_butler/_direct_butler.py:1145, in DirectButler.get(self, datasetRefOrType, dataId, parameters, collections, storageClass, timespan, **kwargs)
#    1086 """Retrieve a stored dataset.
#    1087
#    1088 Parameters
#    (...)
#    1142 ``exposure`` is a temporal dimension.
#    1143 """
#    1144 _LOG.debug("Butler get: %s, dataId=%s, parameters=%s", datasetRefOrType, dataId, parameters)
# -> 1145 ref = self._findDatasetRef(
#    1146     datasetRefOrType,
#    1147     dataId,
#    1148     collections=collections,
#    1149     datastore_records=True,
#    1150     timespan=timespan,
#    1151     **kwargs,
#    1152 )
#    1153 return self._datastore.get(ref, parameters=parameters, storageClass=storageClass)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-9.0.0/share/eups/Linux64/daf_butler/g427f673a11+89552d51e6/python/lsst/daf/butler/direct_butler/_direct_butler.py:899, in DirectButler._findDatasetRef(self, datasetRefOrType, dataId, collections, predict, run, datastore_records, timespan, **kwargs)
#     897         if collections is None:
#     898             collections = self._registry.defaults.collections
# --> 899         raise DatasetNotFoundError(
#     900             f"Dataset {datasetType.name} with data ID {dataId} "
#     901             f"could not be found in collections {collections}."
#     902         )
#     903 if datasetType != ref.datasetType:
#     904     # If they differ it is because the user explicitly specified
#     905     # a compatible dataset type to this call rather than using the
#     906     # registry definition. The DatasetRef must therefore be recreated
#     907     # using the user definition such that the expected type is
#     908     # returned.
#     909     ref = DatasetRef(
#     910         datasetType, ref.dataId, run=ref.run, id=ref.id, datastore_records=ref._datastore_records
#     911     )
#
# DatasetNotFoundError: Dataset calexp with data ID {instrument: 'LSSTComCamSim', detector: 0, visit: 7024062500024} could not be found in collections ('LSSTComCamSim/nightlyValidation',).

# %%
# Determine which dataset types exist in the collection
for datasetType in registry.queryDatasetTypes():
    if registry.queryDatasets(datasetType, collections=collection).any(execute=False, exact=False):
        # Limit search results to the data products
        if ('_config' not in datasetType.name) and ('_log' not in datasetType.name) and ('_metadata' not in datasetType.name) and ('_resource_usage' not in datasetType.name):
            print(datasetType)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Determine which dataset types exist in the collection
# ----> 2 for datasetType in registry.queryDatasetTypes():
#       3     if registry.queryDatasets(datasetType, collections=collection).any(execute=False, exact=False):
#       4         # Limit search results to the data products
#       5         if ('_config' not in datasetType.name) and ('_log' not in datasetType.name) and ('_metadata' not in datasetType.name) and ('_resource_usage' not in datasetType.name):
#
# NameError: name 'registry' is not defined

# %%
list(butler.registry.queryDatasets('visitSummary'))
# Out:
# [DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024061800022, band: 'g', day_obs: 20240618, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/0', id=179e93e5-bb52-4825-b5b9-c5c9f0244123),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024061800042, band: 'i', day_obs: 20240618, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/0', id=bf598c4f-12d5-43b8-88f5-5b94faaea056),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024061800075, band: 'i', day_obs: 20240618, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/0', id=abdf2266-2e52-48bf-b10b-c40ec1ed1540),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024061800074, band: 'i', day_obs: 20240618, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=dfee6523-c55c-4b95-b7af-e6851002375d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500035, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=6fac6bad-930e-418f-a57f-2f06266122fe),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500036, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=2a6856a4-1ee4-406e-8b9c-3861e55dd053),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500037, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a1f0a194-f412-48ca-b0d6-62fd283a4c4a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500038, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=3ba0c7ea-c60a-4cc3-bd61-f4aa0f334beb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500039, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=aa4daa52-278c-4aa9-af17-37900b8e7f2b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500040, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=957d3ce2-acaf-4cc1-b978-069cdb4cf668),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500041, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=ed6fb99b-fe3b-4dd4-b685-837000643855),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500046, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=2ede80ec-636a-43d8-8d00-4e3f881988e2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500047, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=550a5866-d9de-4884-b87c-282062a50095),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500048, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a53dcc5a-74cf-4834-be44-8f69fcd64019),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500055, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=33839253-1e62-46d2-9222-8ac6c652d8b2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500056, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=ca1f196f-a0ea-4475-8368-43779d9d927e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500057, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=f4077b17-2b53-415c-b680-5d0494775bc0),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500063, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=ed16e40c-b129-4379-a046-ac53540e772b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500066, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=85644e7b-6da4-43f4-a861-fb1e6b0a0a89),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500069, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=81f14895-d30f-49e1-a0b1-18da76e916ba),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500072, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=6fcd8eda-eef5-44cf-8f1d-a296be5c6ede),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500075, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=3a8bf0c3-bf3a-4ca8-b736-9679427e13ce),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500078, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=07c7d4ee-382a-4ba3-a47a-b11ca21198f1),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500081, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=8ce98106-63ae-4e82-b8e8-6011ced8511c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500084, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=b99e4747-fb96-46ee-ad6d-9984ab9be08b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500087, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=fd12439e-d259-4f46-ae3a-84ae3f6c61fd),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500099, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=b8aab63d-9604-4df4-86fe-4171b2ad95dd),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500102, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=62101f3c-1381-414d-acb3-1dec0a76ad12),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500105, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=87e22d81-a2e9-4e11-94c9-6707654cae9a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500120, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=c8dd52c0-0ef6-450a-9e49-b45f550ffea8),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500123, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=b71ef9f9-375c-4b0d-bc44-ac06f68b9d1b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500126, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=83a26b07-2ded-43e5-a03c-61723c624925),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500130, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=51f2c969-064d-4454-b5d4-a28c561f8c35),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500131, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=e7f8d5a7-9054-4dac-8a14-217ca1fda74c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500132, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=5954a677-93f8-4c67-a803-3ea2b14ca3bc),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500133, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=48992156-deed-4b4b-b2be-a91869c97299),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500134, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=aca43ebb-1cb5-49d3-80a6-ae5e11cb0566),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500135, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=abca6ac8-10f9-4903-9766-587349d67f40),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500136, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=374d3c22-e85b-43cc-aba2-b2c1c8911931),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500138, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=ad69b0c2-1c13-4254-85e9-8848cf11625b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500137, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=fc21d5f2-857c-4c33-9f2d-8afe075ef9b6),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500139, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=17d5d664-8c04-4bf5-ac2c-4ddb7861c836),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500140, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=036d6573-6058-4bce-8344-92a209abd5a1),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500143, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=a396ae7b-55da-422c-b357-56d61dbebd62),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500144, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=176a0231-e9cb-4a3e-8c45-e66a6c08b32d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500145, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=331798e6-16ed-45a0-b51a-e2add19b3956),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500146, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=653856c5-fe40-4a5d-b8e5-3a75da298b01),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500147, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=72456226-30a9-4950-8536-ffd9ee30b1d9),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500149, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=953030e5-11c4-4fa8-b184-82a632ce77c2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500150, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=e1cbd948-4981-4357-a59f-a7aa4c6e642d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500151, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=40e1e827-8a5f-4435-81ea-acf13a25ce78),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500152, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=11fde0e5-3abd-4107-b50a-6ba1fe3150f5),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500153, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=216aa2b8-6788-4ddc-9cd0-5a6ca9de32ac),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500154, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=1cf6603a-8342-4df0-8b61-a21f45680037),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500155, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=74dda704-90e6-4367-b9be-8a81872cd5ae),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500156, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=e38300da-e30b-476c-bcb2-80d0858dedf1),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500157, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=8e87386d-102f-4518-9d86-a071f32fb678),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500158, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=e563f010-df8e-4a52-b8c9-658e8d7c0484),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500159, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=0a6da3a9-7d39-423e-b2ab-aace254ab0e9),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500160, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=6ef90b92-5d25-4773-a76a-fbc4982b690c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500161, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=97b86c04-f997-47cb-acd3-31bba52bd8b0),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500162, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=fef0009e-0cfe-4877-9090-15fe958cc0f1),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500163, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=56c0b295-91b6-455a-8d96-5ed933eb6219),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500164, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=751a7ddb-cd8a-42c8-98b3-656c6751cb56),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500165, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=bf98bea2-b52f-48db-91d2-19c446cf3d07),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500166, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=ef09deca-8cca-41c1-8bec-e53fc79a238a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500167, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=832f5130-82ea-4512-8590-c918d30c4855),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500168, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=61e65530-6567-4bd0-a2f9-dd8300f3e05a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500169, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=4f3e8961-a8a0-448a-bc07-c0d99b40296b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500170, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=33aae957-3072-44ad-ad06-4e032960e3f8),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500171, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=ac1303db-4f3f-4ee0-ac31-cdd84a75d443),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500172, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=4ba9c91d-2249-4749-9270-484b2fc0ec26),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500173, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a69ae54b-36f1-470e-bd96-46a86cf5b70e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500174, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=fb025429-c0ec-4cc7-84a1-c4db77a2dc88),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500175, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=0f52465f-c143-4231-8daa-c1ffed30fd60),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500176, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=8e1258a9-1ec8-4242-958d-33d950866940),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500177, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=38acf68d-7769-4950-8188-db661b302c1c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500178, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=9ea2b954-5c78-4f6c-b375-2acd74cf8fa7),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500179, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=979cacfa-d0ff-49ad-b96a-cb839454d2f4),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500180, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=ecb3ec0c-af18-4220-86f4-9e3ce6470383),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500181, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=e14a4727-192a-46e2-9c0a-3321ce868dfd),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500182, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=b1fd2205-51f3-4ce1-be2e-036492c99678),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500183, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=6efaf470-5fd5-4a41-b22d-fb86380daecf),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500184, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=cb288418-06e7-450f-a088-7885e23612a7),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500185, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=72ac5115-09ff-49fe-82c0-65edac5b3ac2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500186, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=d2243ce3-bd58-4faf-9165-4e0ba6d69daa),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500187, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=bbb70eda-b36e-432f-b119-16ceb98a053c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500188, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=d66e29be-df1a-4c47-b8fc-c4237e3e41bd),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500189, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=4dac0d57-e70d-4094-b4e5-278fd9c8afc1),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500190, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=c70fedfa-94b5-478a-9e90-6281cb44f10e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500191, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=907018b8-36e3-46b3-ba18-0fd7f03a181e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500192, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a4e6db2f-bef7-47e0-a41f-f5cc14d074d2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500193, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=661390db-1807-4be3-a07d-38875f292256),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500194, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=68bd0dc3-37e7-4b96-a3ab-9d8601eb20ac),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500195, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=065e44da-301b-4fc5-a9ec-6147d4eea7bf),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500196, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=f8ba0629-f91c-4a50-9b97-9824ae31befc),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500197, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=5b3f4b40-9a64-401d-9d57-9628acbbe0fb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500198, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=3f56b06f-62b4-4253-aee9-78360d7a0f7d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500199, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=d8646734-3712-4349-967d-a97e02f00ddb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500200, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=5ad78056-4961-4828-9d4e-8909b7a76654),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500201, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=5448f77f-ccca-43e4-8c98-aed06873cd23),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500202, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=b8d09822-16e2-47ab-8558-ed032191e387),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500203, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=88ef14cd-48f8-4b15-b46c-a9a8640549fc),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500204, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=f01486dd-791a-43d1-8e38-7a4b6c0334fa),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500205, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a503656f-15ce-4dd3-a2b1-53cbc34f602a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500206, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=7009ebfc-66d8-4e0c-be20-e082a35b0557),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500207, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=2c364ff0-5bfc-4d43-88f1-afc7b60b9b4e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500208, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=3d247788-5955-4131-8ff0-7de0a934de57),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500209, band: 'i', day_obs: 20240625, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=856dc947-16dc-4e1b-ae31-da45c91867bb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500210, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=090a5566-45ad-49f1-85a0-aff4a13ee0a9),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500211, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=50604fd1-b711-44a6-a954-4ee7d5aedd6d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500212, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=71914765-1078-464a-8862-4a288b4c8a0e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500213, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=c7b79c2b-5fa7-4da5-ade4-7d450b72fd7e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500214, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=8512255b-8009-423e-9faa-3b147da741f2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500215, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=03761fd3-f062-4870-8715-867b8bf16c1a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500216, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=84492b7a-95a4-4a1c-91df-694562c48ccc),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500217, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=8dfb9438-0f67-44b7-908d-88ff30933882),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500218, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=fe35b618-c2d6-4b33-b85f-ee01933398da),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500219, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=7a2b4c5d-844e-441f-848f-2ffdfa6c14a6),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500220, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=bf1416f4-ce85-45ec-bb20-66d7c42d41d5),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500221, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=22a1d8b6-e678-49b1-998a-9507fba8f4c9),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500222, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=e01e93ef-a44e-483b-8eb9-21eedb1ecf71),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500223, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=27b8ed60-7033-4ee7-9df8-ed7b58afc746),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500224, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=c693e240-5c9d-4ca7-9eab-3f3289abc535),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500225, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=1867c8ca-be61-4c3c-9d8f-6175d044f4da),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500226, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=17b72728-c60c-4522-a489-e27dfb9c1056),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500227, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=1a2f7bfd-eb20-4da9-8496-e77a16b91d85),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500228, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=2578c489-cfb6-4a62-87db-7620eb16b5c2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500229, band: 'g', day_obs: 20240625, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=8a836cf5-f28d-44e3-8a08-a0398c5c015e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500230, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=7fd5df8e-bf87-4654-b68d-c540a22172d9),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500231, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=082708d1-1c00-4669-9bd9-ee81bbdf3c23),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500232, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=f92d9230-e1b3-40cc-a47d-5a3b840a33d2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500233, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=fccb7da1-f4c3-4d76-bc11-ff664691f0ee),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500234, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=5147fb9e-0a6f-4a92-86d4-7e5987c16604),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500235, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=29cad8e8-9d3a-4201-a06d-3fd62da7f78d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500236, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=f0359a79-718e-4e32-9c39-b353eb682e57),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500237, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=81b1c550-366a-42d2-84c7-49f10422ed68),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500238, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=c55ef32c-97b4-44ae-a63c-c52ff8fc33af),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500239, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=aabe6be5-b905-4d52-a51f-98475a3555bd),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500240, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=357c7f9c-c9cd-4ecf-8ac2-6b5d0b2e57ff),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500241, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=fa0b4666-cc9e-426f-b8e0-19b4a883adb6),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500242, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=4e415698-42db-49c9-a110-182750282351),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500243, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=e2ad5cbb-804a-455a-8c5b-ccb1c067b80b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500244, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=dd7348b3-eaec-48ba-a732-8f852477bbcb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500245, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=dc687fc7-aa4d-412c-87c6-9546c28c7844),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500246, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=053fbb63-1cd3-45e8-a047-248bf338277f),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500247, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=bb8b6b0f-8ff7-4888-8b2a-e1054d557c15),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500248, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=9fa2f068-a7b7-4c00-8490-86395bfd061e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500249, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=801b8295-f255-4be0-930d-4fe833642da9),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500250, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=d8f77e56-f878-45ad-8fb9-91416dd81da5),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500251, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=b1d3bfd6-e126-470e-a705-179de2ba33b7),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500252, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=69e3afe7-9e26-4b87-9e36-59a216b1855c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500253, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=4b8e6f01-a67f-49c4-bf55-e8defe306702),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500254, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=b2c34ef5-5dea-4c9a-a405-61f6004d43ca),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500255, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=7b369343-34fe-4159-8516-3d0af17c11de),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500256, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=f830b382-7a49-4293-a53a-bd7403aadb9a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500257, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=1664539d-c150-42ac-bc38-34743f4c462b),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062500258, band: 'r', day_obs: 20240625, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=29a19032-9636-4928-9344-9cb8864eb281),
# ...
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600360, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=4b14dcef-f98b-4f5a-ab29-986324798a2d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600361, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=beab0a40-a1bc-4250-8069-6ac2bc45af7d),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600362, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=810cae16-2bfb-4e0b-a331-a5483361382a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600363, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=15c399d9-f1a4-4e37-a294-c38813d383cb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600364, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=ffc58574-a37e-41fe-9494-e8df92ed41df),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600365, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=8d119e4c-fea3-4740-8eae-f6a1f4c747f6),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600366, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=0e8428fb-10c0-4185-8cc1-474afa57fab6),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600367, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=9831894b-8851-48ea-8152-b6991cc81bc0),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600368, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a9e1c510-58aa-46d2-8c09-3fc72d835828),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600369, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=45ec9912-8764-4919-ae25-1118c366f2f4),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600370, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=d9942c99-e2f1-4144-a3e8-9f548311c875),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600371, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=9b9a4a77-e3c4-4b66-a764-9d221881d707),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600372, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=82cab8e2-d9dc-4353-beb4-6942d00ad262),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600373, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=25a7334f-9e89-4185-b10e-b70c4bb89feb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600374, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=9570f525-9e5c-4f69-842f-cb0f523b5395),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600375, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=ada2d69b-f772-430b-af21-454674c68744),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600377, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=0e59cd2b-c877-4ce4-bb15-7c24cda4a5cb),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600378, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=361ed130-46c9-490c-a128-2e73f157d875),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600380, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=00a9f9a6-64d6-481d-b390-3a2f54d6a7b3),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600382, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=57eb2fda-eb74-4432-a873-6217acb77982),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600384, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=5dd0139a-b2eb-4d71-882c-cc4a8017e1b4),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600385, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=1611203d-fc5e-4119-ae56-1f32196e062f),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600386, band: 'i', day_obs: 20240626, physical_filter: 'i_06'}, run='LSSTComCamSim/nightlyValidation/1', id=a449b2d9-35cd-45af-bff0-35c1c9ad35c7),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600388, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=585009f8-6ca4-48eb-9f83-bfbaab3a779a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600389, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=d3a95d39-caa0-4b7e-bd2f-400aeaabeca0),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600390, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=da514838-9286-471b-83fc-23ba2ac23010),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600391, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=1e59e3b3-9f8e-4762-94f9-4dc01dda821a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600392, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=ddf94112-02b1-4dc6-a676-3bdbc56e56a8),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600393, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=defb1cbc-6acf-43e2-a2ac-ec06b074497e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600394, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=4a7aa498-de04-4856-b22a-0df0ec5f681e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600395, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=0dc00e40-be49-414b-9ce5-2c1a318875e7),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600396, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=26d571c9-6198-492c-b9cb-5e8b182ea559),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600397, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=f2e84062-0677-466a-91a5-bc1dafbf2f23),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600399, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=e8c33e65-d9be-4f2b-8526-ba9b44932da2),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600400, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=1d5bbaea-7efe-4053-a797-640ae42195c3),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600401, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=0cd0270b-5609-4e47-8681-d0ec5dd75d6a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600402, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=5ab93e71-3e99-4f61-8a7a-27b06d503195),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600403, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=5c80fe26-1d6e-4a51-9d77-4a44ecc0ddab),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600404, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=880eadcf-32ce-40a1-8db9-6e72a5f96aa5),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600405, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=e7e957ed-c9ec-4810-bba1-87313f6d52bf),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600406, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=167a9b00-6391-4470-9efc-df0d187f41c4),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600407, band: 'g', day_obs: 20240626, physical_filter: 'g_01'}, run='LSSTComCamSim/nightlyValidation/1', id=a57b77ba-de00-4beb-8813-dc1dba52361a),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600408, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=cd8ca037-4340-42cc-9dd3-e82fc7a3424c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600409, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=21f8c52f-f7df-4871-91ca-7b0ecc629b64),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600410, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=b9755b5c-7615-41a3-8141-8e043109a40e),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600411, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=b5bd91d7-e2a7-4876-9792-0a4a7893c971),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600412, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=2037f24c-179d-4568-a600-c0dc3ab64cef),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600413, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=7c8fb935-57f4-4965-a061-95aa3179a503),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600414, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=5626717b-fce8-47eb-a50c-15fa9b85ab52),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600416, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=9c58eedb-fc2c-4017-950e-027d988d8802),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600418, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=9b79a425-2e52-42fe-a4e6-249ec241188c),
#  DatasetRef(DatasetType('visitSummary', {band, instrument, day_obs, physical_filter, visit}, ExposureCatalog), {instrument: 'LSSTComCamSim', visit: 7024062600419, band: 'r', day_obs: 20240626, physical_filter: 'r_03'}, run='LSSTComCamSim/nightlyValidation/1', id=4a341a91-8adb-4889-9456-6531263169de),
#  ...]
